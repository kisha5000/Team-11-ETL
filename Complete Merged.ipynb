# %% [markdown]
# # ETL Project - Gun Violence

# %%
#import dependencies
import pandas as pd
from sqlalchemy import create_engine
from secret import username, password
import requests
from bs4 import BeautifulSoup
URL = "https://en.wikipedia.org/wiki/Gun_laws_in_the_United_States_by_state"

# %% [markdown]
# # Mass Shooting, Accidental Deaths and Accidental Injuries - Extract and Transform

# %%
df_1 = pd.read_csv("Resources/General_Accidental_Death.csv")
df_2 = pd.read_csv("Resources/General_Accidental_Injuries.csv")
df_3 = pd.read_csv("Resources/Mass_shootings.csv")

# %%
df_1.columns = ['ID', 'Date', 'State', 'City', 'Address', 'Killed', 'Injured', 'Op']
df_2.columns = ['ID', 'Date', 'State', 'City', 'Address', 'Killed', 'Injured', 'Op']
df_3.columns = ['ID', 'Date', 'State', 'City', 'Address', 'Killed', 'Injured', 'Op']

del df_1['Op']
del df_2['Op']
del df_3['Op']

df_1['Type'] = "Accident"
df_1['Type'] = "Accident"
df_3['Type'] = "Mass Shooting"

# %%
df = pd.DataFrame(columns = ['ID', 'Date', 'State', 'City', 'Address', 'Killed', 'Injured'])

# %%
df = df.append(df_1)
df = df.append(df_2)
df = df.append(df_3)

# %%
df.head()
# Out:
#         ID       Date       State          City  \
# 0  1747443  27-Jul-20     Arizona        Tucson
# 1  1747425  26-Jul-20   Tennessee     Nashville
# 2  1748086  26-Jul-20        Ohio  Grand Rapids
# 3  1746886  26-Jul-20  California   Los Angeles
# 4  1746495  25-Jul-20     Florida         Largo
#
#                              Address Killed Injured      Type
# 0               25 W Calle Concordia      1       0  Accident
# 1  500 block of Charles E Davis Blvd      1       0  Accident
# 2       17000 block of Wapakoneta Rd      1       0  Accident
# 3  Hollywood Blvd and N Highland Ave      1       1  Accident
# 4                  71000 Ulmerton Rd      1       0  Accident

# %%
# Incidents
df.head()
# Out:
#         ID       Date       State          City  \
# 0  1747443  27-Jul-20     Arizona        Tucson
# 1  1747425  26-Jul-20   Tennessee     Nashville
# 2  1748086  26-Jul-20        Ohio  Grand Rapids
# 3  1746886  26-Jul-20  California   Los Angeles
# 4  1746495  25-Jul-20     Florida         Largo
#
#                              Address Killed Injured      Type
# 0               25 W Calle Concordia      1       0  Accident
# 1  500 block of Charles E Davis Blvd      1       0  Accident
# 2       17000 block of Wapakoneta Rd      1       0  Accident
# 3  Hollywood Blvd and N Highland Ave      1       1  Accident
# 4                  71000 Ulmerton Rd      1       0  Accident

# %% [markdown]
# And the Cleaning begins...

# %%
dropped_df=df[df.ID != '#######']
dropped_df
# Out:
#           ID       Date       State          City  \
# 0    1747443  27-Jul-20     Arizona        Tucson
# 1    1747425  26-Jul-20   Tennessee     Nashville
# 2    1748086  26-Jul-20        Ohio  Grand Rapids
# 3    1746886  26-Jul-20  California   Los Angeles
# 4    1746495  25-Jul-20     Florida         Largo
# ..       ...        ...         ...           ...
# 495  1475208   9-Aug-19    Illinois       Chicago
# 496  1472641   7-Aug-19    Missouri   Saint Louis
# 497  1469344   5-Aug-19    New York      Brooklyn
# 498  1527721   4-Aug-19   Louisiana  Lake Charles
# 499  1468190   4-Aug-19    Illinois       Chicago
#
#                                Address Killed Injured           Type
# 0                 25 W Calle Concordia      1       0       Accident
# 1    500 block of Charles E Davis Blvd      1       0       Accident
# 2         17000 block of Wapakoneta Rd      1       0       Accident
# 3    Hollywood Blvd and N Highland Ave      1       1       Accident
# 4                    71000 Ulmerton Rd      1       0       Accident
# ..                                 ...    ...     ...            ...
# 495       7300 block of S Artesian Ave      0       4  Mass Shooting
# 496           4900 block of Plover Ave      3       1  Mass Shooting
# 497                    216 Buffalo Ave      0       4  Mass Shooting
# 498                       110 Pryce St      0       4  Mass Shooting
# 499                 1800 S Kildare Ave      1       7  Mass Shooting
#
# [1500 rows x 8 columns]

# %%
dropped_df[dropped_df.ID == '#######']
# Out:
# Empty DataFrame
# Columns: [ID, Date, State, City, Address, Killed, Injured, Type]
# Index: []

# %%
dropped_df.duplicated(subset=['ID'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Length: 1500, dtype: bool

# %%
dropped_df['ID'].nunique()
# Out:
# 1475

# %%
dropped_df[dropped_df.duplicated(subset=['ID']) == True]
# Out:
#           ID       Date           State                                City  \
# 18   1740578  20-Jul-20           Texas                           Arlington
# 33   1738740  18-Jul-20  South Carolina                    North Charleston
# 95   1726663   5-Jul-20         Georgia                             Atlanta
# 112  1723897   3-Jul-20         Alabama                 Birmingham (Hoover)
# 134  1718645  26-Jun-20   West Virginia                        Cottageville
# 157  1711272  20-Jun-20        Michigan                             Saginaw
# 175  1706994  16-Jun-20            Iowa                          Fort Dodge
# 176  1707253  16-Jun-20        Illinois                             Chicago
# 355  1670035   1-May-20         Alabama                              Pinson
# 417  1656735  10-Apr-20         Florida  Palm Beach Gardens (Riviera Beach)
# 17   1741838  21-Jul-20        Illinois                             Chicago
# 55   1726446   5-Jul-20           Texas                             Houston
# 73   1723897   3-Jul-20         Alabama                 Birmingham (Hoover)
# 120  1711272  20-Jun-20        Michigan                             Saginaw
# 121  1710849  20-Jun-20       Wisconsin                          Janesville
# 128  1706994  16-Jun-20            Iowa                          Fort Dodge
# 149  1703055  11-Jun-20           Texas                             Houston
# 171  1695586   2-Jun-20       Wisconsin                              Racine
# 212  1681602  17-May-20  South Carolina                          Charleston
# 222  1676515  10-May-20       Louisiana                         Baton Rouge
# 288  1629042  25-Feb-20        Illinois                             Chicago
# 315  1603241  22-Jan-20      Washington                             Seattle
# 347  1577046  20-Dec-19     Mississippi                          Waynesboro
# 359  1562043   1-Dec-19       Louisiana                       Cotton Valley
# 407  1530965  20-Oct-19           Texas                         Port Arthur
#
#                              Address Killed Injured           Type
# 18    4100 block of Maple Springs Dr      1       1            NaN
# 33              4755 Saul White Blvd      1       2            NaN
# 95                     1192 Pryor Rd      1       2            NaN
# 112         2000 Riverchase Galleria      1       3            NaN
# 134                              NaN      1       1            NaN
# 157     Livingston Dr and Tausend St      1       3            NaN
# 175         900 block of 10th Ave SW      2       2            NaN
# 176   7600 block of N Marshfield Ave      1       1            NaN
# 355  9100 block of Cedar Mountain Rd      1       1            NaN
# 417          1000 Block of W 26th St      1       1            NaN
# 17                    1018 W 79th St      0      15  Mass Shooting
# 55      Service Rd and Holcombe Blvd      0       4  Mass Shooting
# 73          2000 Riverchase Galleria      1       3  Mass Shooting
# 120     Livingston Dr and Tausend St      1       3  Mass Shooting
# 121                     6530 S US-51      0       5  Mass Shooting
# 128         900 block of 10th Ave SW      2       2  Mass Shooting
# 149                 5840 Glenmont Dr      2       4  Mass Shooting
# 171    Kewaunee St and Michigan Blvd      0       5  Mass Shooting
# 212                     23 Cannon St      0       4  Mass Shooting
# 222                    2944 Plank Rd      0       5  Mass Shooting
# 288                   1238 E 79th St      1       4  Mass Shooting
# 315                     1530 3rd Ave      1       7  Mass Shooting
# 347                        Turner St      1       6  Mass Shooting
# 359               116 Hawthorne Loop      2       3  Mass Shooting
# 407      1100 block of Vicksburg Ave      1       3  Mass Shooting

# %%
clean_dropped_df=dropped_df.drop_duplicates(subset=['ID'])
clean_dropped_df.head()
# Out:
#         ID       Date       State          City  \
# 0  1747443  27-Jul-20     Arizona        Tucson
# 1  1747425  26-Jul-20   Tennessee     Nashville
# 2  1748086  26-Jul-20        Ohio  Grand Rapids
# 3  1746886  26-Jul-20  California   Los Angeles
# 4  1746495  25-Jul-20     Florida         Largo
#
#                              Address Killed Injured      Type
# 0               25 W Calle Concordia      1       0  Accident
# 1  500 block of Charles E Davis Blvd      1       0  Accident
# 2       17000 block of Wapakoneta Rd      1       0  Accident
# 3  Hollywood Blvd and N Highland Ave      1       1  Accident
# 4                  71000 Ulmerton Rd      1       0  Accident

# %%
clean_violence_df=clean_dropped_df.drop(['Type'],axis=1)
clean_violence_df.head()
# Out:
#         ID       Date       State          City  \
# 0  1747443  27-Jul-20     Arizona        Tucson
# 1  1747425  26-Jul-20   Tennessee     Nashville
# 2  1748086  26-Jul-20        Ohio  Grand Rapids
# 3  1746886  26-Jul-20  California   Los Angeles
# 4  1746495  25-Jul-20     Florida         Largo
#
#                              Address Killed Injured
# 0               25 W Calle Concordia      1       0
# 1  500 block of Charles E Davis Blvd      1       0
# 2       17000 block of Wapakoneta Rd      1       0
# 3  Hollywood Blvd and N Highland Ave      1       1
# 4                  71000 Ulmerton Rd      1       0

# %%
mapping =clean_dropped_df[['State', 'City']].drop_duplicates()

del df['State']

# %% [markdown]
# # Mapping Tables

# %%
type_df=clean_dropped_df.drop(['Date','City','State','Address','Killed','Injured'],axis=1)
type_df.head()
# Out:
#         ID      Type
# 0  1747443  Accident
# 1  1747425  Accident
# 2  1748086  Accident
# 3  1746886  Accident
# 4  1746495  Accident

# %%
type_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1475 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      1475 non-null   object
#  1   Type    985 non-null    object
# dtypes: object(2)
# memory usage: 34.6+ KB

# %%
type_df.fillna('Unknown',inplace=True)

type_df.head()
# Out:
#         ID      Type
# 0  1747443  Accident
# 1  1747425  Accident
# 2  1748086  Accident
# 3  1746886  Accident
# 4  1746495  Accident

# %%
type_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1475 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      1475 non-null   object
#  1   Type    1475 non-null   object
# dtypes: object(2)
# memory usage: 34.6+ KB

# %%
# city_mapping
mapping.head()
# Out:
#         State          City
# 0     Arizona        Tucson
# 1   Tennessee     Nashville
# 2        Ohio  Grand Rapids
# 3  California   Los Angeles
# 4     Florida         Largo

# %%
new_map_df=pd.DataFrame(mapping)

# %%
new_map_df.duplicated(subset=['City'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 470    False
# 475    False
# 477    False
# 480    False
# 491     True
# Length: 745, dtype: bool

# %%
new_map_df['City'].nunique()
# Out:
# 696

# %%
new_map_df[new_map_df.duplicated(subset=['City']) == True]
# Out:
#               State           City
# 154       Tennessee        Jackson
# 237         Georgia      Lexington
# 280         Georgia       Columbus
# 334  South Carolina    Springfield
# 343        Virginia     Waynesboro
# 355        New York      Frankfort
# 396        Missouri       Columbia
# 413         Georgia        Decatur
# 441        Michigan   Grand Rapids
# 456    Pennsylvania         Gordon
# 490    Pennsylvania       Columbia
# 493        Illinois         Aurora
# 60         Kentucky      Lancaster
# 62          Arizona       San Jose
# 76             Ohio         Warren
# 89          Georgia       Savannah
# 92       New Jersey        Jackson
# 98       New Jersey         Newark
# 100       Tennessee    Springfield
# 195        New York       Harrison
# 210          Alaska        Houston
# 225         Georgia         Albany
# 301        Missouri       Bismarck
# 322         Indiana      Lafayette
# 330         Alabama         Auburn
# 340    Pennsylvania  Elizabethtown
# 345         Alabama      Fairfield
# 351        Michigan        Jackson
# 391        Missouri         Quincy
# 414       Tennessee      Lafayette
# 456  North Carolina      Lexington
# 463           Texas      Cleveland
# 486         Arizona       Glendale
# 13         Virginia      Fairfield
# 28          Florida        Madison
# 44         New York      Rochester
# 46         Virginia     Alexandria
# 52   South Carolina     Greenville
# 62      Mississippi     Greenville
# 88          Alabama          Akron
# 197         Alabama       Danville
# 244   Massachusetts    Springfield
# 304     Mississippi   Philadelphia
# 330        Illinois       Danville
# 375      California       Richmond
# 403           Texas     Greenville
# 424          Kansas    Kansas City
# 445      California     Wilmington
# 491     Mississippi      Greenwood

# %%
clean_map_df=new_map_df.drop_duplicates(subset=['City'])
clean_map_df
# Out:
#           State                         City
# 0       Arizona                       Tucson
# 1     Tennessee                    Nashville
# 2          Ohio                 Grand Rapids
# 3    California                  Los Angeles
# 4       Florida                        Largo
# ..          ...                          ...
# 467       Texas                       Odessa
# 470    Maryland                    Frederick
# 475  New Mexico                        Hobbs
# 477    Maryland  Temple Hills (Camp Springs)
# 480     Georgia                       Dublin
#
# [696 rows x 2 columns]

# %%
clean_map_df['City'].nunique()
# Out:
# 696

# %%
clean_map_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 696 entries, 0 to 480
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   State   696 non-null    object
#  1   City    696 non-null    object
# dtypes: object(2)
# memory usage: 16.3+ KB

# %% [markdown]
# # Web Scrape of Wikipedia on Gun Laws - Extract and Transform

# %%
states = pd.read_html(URL)
states = states[1:-3]
states
# Out:
# [                                     Subject/Law Long guns Handguns  \
#  0             State permit required to purchase?        No       No
#  1                          Firearm registration?        No       No
#  2                        Owner license required?        No       No
#  3           Permit required for concealed carry?       NaN      Yes
#  4                Permit required for open carry?        No       No
#  5        State preemption of local restrictions?       Yes      Yes
#  6                            Assault weapon law?        No       No
#  7                        NFA weapons restricted?        No       No
#  8  Background checks required for private sales?        No       No
#
#     Relevant statutes                                              Notes
#  0                NaN                                                NaN
#  1                NaN                                                NaN
#  2                NaN                                                NaN
#  3                NaN  Alabama is a shall-issue state for concealed c...
#  4                NaN  Open carry is generally permitted, but handgun...
#  5                NaN  "...the Legislature hereby occupies and preemp...
#  6                NaN                                                NaN
#  7                NaN  Any Other Weapons (AOWs) disguised as walking ...
#  8                NaN                                                NaN  ,
#                                        Subject/Law Long guns Handguns  \
#  0              State permit required to purchase?        No       No
#  1                           Firearm registration?        No       No
#  2                             Assault weapon law?        No       No
#  3                         Owner license required?        No       No
#  4            Permit required for concealed carry?       NaN       No
#  5                 Permit required for open carry?        No       No
#  6         State Preemption of local restrictions?       Yes      Yes
#  7                         NFA weapons restricted?        No       No
#  8            Shall Certify?[clarification needed]       Yes      Yes
#  9                         Peaceable Journey laws?        No       No
#  10  Background checks required for private sales?        No       No
#
#                   Relevant Statutes  \
#  0                             None
#  1                             None
#  2                             None
#  3                             None
#  4   AS 18.65.700 through 18.65.778
#  5                             None
#  6                     AS 29.35.145
#  7                             None
#  8                     AS 18.65.810
#  9                             None
#  10                            None
#
#                                                  Notes
#  0                                                 NaN
#  1                                                 NaN
#  2                                                 NaN
#  3                                                 NaN
#  4   May carry concealed without permit, though per...
#  5            May carry openly without permit/license.
#  6   Municipalities may enact and enforce local reg...
#  7                                                 NaN
#  8                       Shall certify within 30 days.
#  9                             Federal rules observed.
#  10                                                NaN  ,
#                                            Subject/Law Long guns Handguns  \
#  0                  State permit required to purchase?        No       No
#  1                      Firearm registration required?        No       No
#  2         Assault weapon prohibition or restrictions?        No       No
#  3                      Magazine Capacity Restriction?        No       No
#  4                             Owner license required?        No       No
#  5                Permit required for concealed carry?       NaN       No
#  6                     Permit required for open carry?        No       No
#  7             State preemption of local restrictions?   Partial  Partial
#  8                             NFA weapons restricted?        No       No
#  9                                      Shall certify?       Yes      Yes
#  10                            Peaceable journey laws?        No       No
#  11      Background checks required for private sales?        No       No
#  12  Lose Right to Possession Indefinitely under Me...       Yes      Yes
#
#               Relevant Statutes  \
#  0                          NaN
#  1               ARS 13-3101(B)
#  2                          NaN
#  3                          NaN
#  4                          NaN
#  5                      SB 1108
#  6                          NaN
#  7                  ARS 13-3108
#  8                  ARS 13-3101
#  9                  ARS 13-3121
#  10                         NaN
#  11                         NaN
#  12  ARS 36-540; ARS 13-925[11]
#
#                                                  Notes
#  0                                                 NaN
#  1   State law requires compliance with the Nationa...
#  2                                                 NaN
#  3                                                 NaN
#  4                                                 NaN
#  5   In Arizona, a person over age 21 may legally c...
#  6   May carry openly without permit/license. Must ...
#  7                                     Explained below
#  8   Law makes possession and use illegal but then ...
#  9                       Shall certify within 60 days.
#  10                            Federal rules observed.
#  11  On May 1, 2017, Governor Ducey signed a bill t...
#  12  A person found persistently or acutely disable...  ,
#                                        Subject/Law Long guns Handguns  \
#  0              State permit required to purchase?        No       No
#  1                           Firearm registration?        No       No
#  2                             Assault weapon law?        No       No
#  3                  Magazine Capacity Restriction?        No       No
#  4                         Owner license required?        No       No
#  5           License required for concealed carry?       NaN      Yes
#  6                License required for open carry?        No      NaN
#  7         State Preemption of local restrictions?       Yes      Yes
#  8                         NFA weapons restricted?        No       No
#  9                                  Shall Certify?       Yes      Yes
#  10                        Peaceable Journey laws?       Yes      Yes
#  11  Background checks required for private sales?        No       No
#
#        Relevant Statutes                                              Notes
#  0                   NaN                                                NaN
#  1                   NaN                                                NaN
#  2                   NaN                                                NaN
#  3                   NaN                                                NaN
#  4                   NaN                                                NaN
#  5   5-73-301 - 5-73-320  Shall-Issue. The Arkansas State Police issue a...
#  6              5-73-120        May not open carry with or without license.
#  7              5-73-120                                                NaN
#  8              5-73-205  All NFA items allowed if in compliance with Fe...
#  9              5-73-112  Shall certify within 15 days. With the enactme...
#  10      5-73-120 (c)(4)  Weapons are allowed if the person is carrying ...
#  11                  NaN                                                NaN  ,
#                                            Subject/Law Long guns Handguns  \
#  0                  State permit required to purchase?   Partial  Partial
#  1                               Firearm registration?       Yes      Yes
#  2                             Owner license required?        No       No
#  3                                 Assault weapon law?       Yes      Yes
#  4                      Magazine capacity restriction?       Yes      Yes
#  5               License required for concealed carry?       NaN      Yes
#  6                                 Open carry allowed?   Partial  Partial
#  7                                      Vehicle carry?        No      Yes
#  8             State preemption of local restrictions?       Yes      Yes
#  9                                Castle doctrine law?       Yes      Yes
#  10                            NFA weapons restricted?       Yes      Yes
#  11                            Peaceable journey laws?        No       No
#  12                                    Waiting period?       Yes      Yes
#  13      Background checks required for private sales?       Yes      Yes
#  14                                      Red flag law?       Yes      Yes
#  15  Background check required for ammunition purch...       Yes      Yes
#  16                   Home-built firearms restriction?       Yes      Yes
#
#       Relevant Statutes (Penal Code except when noted)  \
#  0                                              §26500
#  1                                              §28150
#  2                                                None
#  3                                      §30500, §30515
#  4                                              §32310
#  5                                              §26150
#  6                                              §26350
#  7                                              §25610
#  8                              §53701 Government Code
#  9                                                 NaN
#  10                             §12220, §12020, §12020
#  11                                                NaN
#  12  §26815(a)[2], §26950-27140 [3], §27540(a) [4],...
#  13                                            § 27545
#  14                                                NaN
#  15                      PC 30312, 30314, 30342, 30370
#  16                                           PC 29180
#
#                                                  Notes
#  0   All firearm sales must be completed through a ...
#  1   The California Department of Justice ("DOJ") r...
#  2   While the Firearm Safety Certificate is requir...
#  3   Illegal to possess, import, or purchase assaul...
#  4   Section 32310 of the Penal Code states that an...
#  5   "May issue," depending on jurisdiction. County...
#  6   Long guns and handguns may be openly carried i...
#  7   A valid California Concealed Weapons License i...
#  8      Most but not all local restrictions preempted.
#  9   California never requires a duty to retreat wh...
#  10  Possession of automatic weapons or short-barre...
#  11  California courts have ruled that large-capaci...
#  12  California has a ten (10) day waiting period f...
#  13  Private party transfers of firearms must be co...
#  14  The police or a person's family member can ask...
#  15  After January 1, 2018 all ammunition purchases...
#  16  After July 1, 2018, any person who wishes to m...  ,
#                                        Subject/Law Long guns Handguns  \
#  0              State permit required to purchase?        No       No
#  1                           Firearm registration?        No       No
#  2                             Assault weapon law?        No       No
#  3                  Magazine Capacity Restriction?       Yes      Yes
#  4                         Owner license required?        No       No
#  5            Permit required for concealed carry?       NaN      Yes
#  6                 Permit required for open carry?        No       No
#  7                     Concealed within a vehicle?       Yes      Yes
#  8         State Preemption of local restrictions?       Yes      Yes
#  9                         NFA weapons restricted?        No       No
#  10                        Peaceable Journey laws?       Yes      Yes
#  11                               Castle Doctrine?       Yes      Yes
#  12                         Stand Your Ground Law?        No       No
#  13  Background checks required for private sales?       Yes      Yes
#  14                                  Red flag law?       Yes      Yes
#
#                                      Relevant Statutes  \
#  0                                                 NaN
#  1                                                 NaN
#  2                                       DRMC § 38-130
#  3                         CRS §§ 18-12-302, 18-12-303
#  4                                                 NaN
#  5                                     CRS § 18-12-203
#  6               CRS § 18-12;DRMC §§ 38-117(b), 38-118
#  7   CRS §§ 18-12-105(2b), 33-6-125;DRMC §§ 38-117(...
#  8                                   CRS § 29-11.7-103
#  9                                     CRS § 18-12-102
#  10       CRS § 18-12-105.6; DRMC §§ 38-117(f), 38-118
#  11                                   CRS § 18-1-704.5
#  12                                                NaN
#  13                                    CRS § 18-12-112
#  14                                         HB 19-1177
#
#                                                  Notes
#  0                                                 NaN
#  1                                                 NaN
#  2   Denver ordinance bans assault weapons. Vail ba...
#  3   After July 1, 2013, magazines holding more tha...
#  4                                                 NaN
#  5   Colorado is a shall issue state for concealed ...
#  6   Legal without permit requirements except in De...
#  7   No permit is required. Pistols may be carried ...
#  8   Local ordinances are preempted by state law, b...
#  9   NFA items are defined as a "dangerous weapon"....
#  10  Denver's restrictions on transport/possession ...
#  11  A legal resident of a property has the right t...
#  12                                                NaN
#  13  For private party transfers of firearms, the s...
#  14  The police may temporarily confiscate firearms...  ,
#                                        Subject/Law Long guns Handguns  \
#  0              State permit required to purchase?       Yes      Yes
#  1                           Firearm registration?   Partial  Partial
#  2                           "Assault Weapon" law?       Yes      Yes
#  3                  Magazine capacity restriction?       Yes      Yes
#  4                         Owner license required?        No       No
#  5            Permit required for concealed carry?       NaN      Yes
#  6                 Permit required for open carry?        No      Yes
#  7                        Vehicle carry permitted?        No      Yes
#  8                                 Duty to inform?        No       No
#  9                                Castle Doctrine?       Yes      Yes
#  10        State preemption of local restrictions?   Partial      Yes
#  11                        NFA weapons restricted?        No       No
#  12                        Peaceable Journey laws?        No       No
#  13  Background checks required for private sales?       Yes      Yes
#  14                                  Red flag law?       Yes      Yes
#
#                              Relevant statutes  \
#  0   CGS 29-33(b), CGS 29–36(f), CGS 29-38m(c)
#  1                                  CGS 53–202
#  2                                  CGS 53–202
#  3                                     53-202w
#  4                               CGS 23-37a(b)
#  5                                   CGS 29–28
#  6                                         NaN
#  7                                         NaN
#  8                                         NaN
#  9                                         NaN
#  10                                  CGS 29–28
#  11                              CGS 53–202(c)
#  12                                  CGS 29–38
#  13                                        NaN
#  14                                        NaN
#
#                                                  Notes
#  0   Certificate of Eligibility for Pistol and Revo...
#  1   Registration required for assault weapons purc...
#  2   Partial ban. Selective fire weapons, some .50 ...
#  3   As of April 4, 2013, magazines holding more th...
#  4   No license/permit is required to own any firea...
#  5   Shall-Issue, with Limited Discretion. Connecti...
#  6   Connecticut is a Licensed Open Carry state. A ...
#  7   A valid Connecticut pistol permit is required ...
#  8   Connecticut is not a duty to inform state. Tho...
#  9   No duty to retreat if you are in your home or ...
#  10  State pre-emption of local ordinances not expl...
#  11  SBR, SBS, DD, suppressors are legal, provided ...
#  12                            Federal rules observed.
#  13  Private party firearm transfers require that a...
#  14  State law allows police, after investigating a...  ,
#                                        Subject/Law Long guns Handguns  \
#  0              State permit required to purchase?        No       No
#  1                           Firearm registration?        No       No
#  2                             Assault weapon law?        No       No
#  3                  Magazine capacity restriction?        No       No
#  4                         Owner license required?        No       No
#  5            Permit required for concealed carry?       NaN      Yes
#  6                 Permit required for open carry?        No       No
#  7         State preemption of local restrictions?      Yes*     Yes*
#  8                         NFA weapons restricted?       Yes      Yes
#  9                         Peaceable Journey laws?        No       No
#  10  Background checks required for private sales?       Yes      Yes
#  11                                  Red flag law?       Yes      Yes
#
#                       Relevant statutes  \
#  0                                  NaN
#  1                                  NaN
#  2                                  NaN
#  3                                  NaN
#  4                                  NaN
#  5                     11 Del.C. § 1441
#  6                                  NaN
#  7                       22 Del.C § 111
#  8                                  NaN
#  9                                  NaN
#  10  147th General Assembly: Chapter 20
#  11               House Bill 302 (2018)
#
#                                                  Notes
#  0                                                 NaN
#  1                                                 NaN
#  2                                                 NaN
#  3                                                 NaN
#  4                                                 NaN
#  5   Delaware is officially a "may issue" state for...
#  6   Open carry without permit is generally lawful....
#  7   Municipalities may regulate only the discharge...
#  8   SBRs and AOWs are legal. The city of Wilmingto...
#  9                             Federal rules observed.
#  10  Private party transfers of firearms to persons...
#  11  If a mental health professional deems that a p...  ,
#                                        Subject/Law Long guns Handguns  \
#  0                    Permit required to purchase?       Yes      Yes
#  1                         Owner license required?       Yes      Yes
#  2                           Firearm registration?       Yes      Yes
#  3           License required for concealed carry?       NaN      Yes
#  4                             Open carry allowed?        No       No
#  5                             Assault weapon law?       Yes      Yes
#  6                  Magazine capacity restriction?       Yes      Yes
#  7                         NFA weapons restricted?       Yes      Yes
#  8                         Peaceable journey laws?        No       No
#  9   Background checks required for private sales?       Yes      Yes
#  10                                Waiting period?       Yes      Yes
#  11                                  Red flag law?       Yes      Yes
#
#       Relevant statutes                                              Notes
#  0                  NaN  The firearm registration process also serves a...
#  1                  NaN  The firearm registration process also serves a...
#  2                  NaN  All firearms except certain black powder firea...
#  3                  NaN  The Metropolitan Police Department shall issue...
#  4                  NaN                          Open carry is prohibited.
#  5                  NaN     Assault weapons and .50 BMG rifles prohibited.
#  6                  NaN  Illegal to possess magazines of more than 10 r...
#  7                  NaN  Automatic firearms, short barreled rifles, sho...
#  8                  NaN                        Federal law (FOPA) applies.
#  9   DC Code §7–2505.02  Private party firearm transfers must be conduc...
#  10                 NaN  After purchasing a firearm, the buyer must wai...
#  11                 NaN                                                NaN  ,
#                                        Subject/Law Long guns Handguns  \
#  0              State permit required to purchase?        No       No
#  1                           Firearm registration?        No       No
#  2                         Owner license required?        No       No
#  3                             Assault weapon law?        No       No
#  4                  Magazine Capacity Restriction?        No       No
#  5            Permit required for concealed carry?       NaN      Yes
#  6                             Open carry allowed?        No       No
#  7         State Preemption of local restrictions?       Yes      Yes
#  8                         NFA weapons restricted?        No       No
#  9                         Peaceable Journey laws?        No       No
#  10                                Duty to inform?        No       No
#  11  Background checks required for private sales?        No       No
#  12                                  Red flag law?       Yes      Yes
#  13                                Waiting period?       Yes      Yes
#
#      Relevant Statutes                                              Notes
#  0   F.S. 790.065 (13)  The sale or transfer of a firearm to a person ...
#  1        F.S. 790.335  It is a felony under Florida law to create, ma...
#  2                None                                                NaN
#  3                None                                                NaN
#  4                None                                                NaN
#  5         F.S. 790.06  Allows concealed possession of handguns, elect...
#  6        F.S. 790.053  Open carry of firearms is generally banned exc...
#  7         F.S. 790.33                       See Preemption section below
#  8        F.S. 790.161  Making, possessing, throwing, projecting, or d...
#  9                None                            Federal rules observed.
#  10               None  Florida law does not require one to disclose o...
#  11               None                                                NaN
#  12       F.S. 790.401  The police can get judicial approval to confis...
#  13      F.S. 790.0655  The mandatory waiting period is 3 days, exclud...  ,
#                                        Subject/Law Long guns Handguns  \
#  0              State permit required to purchase?        No       No
#  1                           Firearm registration?        No       No
#  2                             Assault weapon law?        No       No
#  3                  Magazine Capacity Restriction?        No       No
#  4                         Owner license required?        No       No
#  5            Permit required for concealed carry?       Yes      Yes
#  6                 Permit required for open carry?        No      Yes
#  7         State Preemption of local restrictions?       Yes      Yes
#  8                         NFA weapons restricted?        No       No
#  9                         Peaceable Journey laws?        No       No
#  10  Background checks required for private sales?        No       No
#
#        Relevant Statutes                                              Notes
#  0                  None                                                NaN
#  1                  None                                                NaN
#  2                  None                                                NaN
#  3                  None                                                NaN
#  4                  None                                                NaN
#  5   O.C.G.A § 16-11-129  Concealed or open carry allowed with permit. S...
#  6   O.C.G.A § 16-11-126  Open carry of handguns allowed with a license ...
#  7   O.C.G.A § 16-11-173  Despite state preemption, several localities c...
#  8                  None                                                NaN
#  9                  None                            Federal rules observed.
#  10                 None                                                NaN  ,
#                                        Subject/Law Long guns Handguns  \
#  0              State permit required to purchase?       Yes      Yes
#  1                           Firearm registration?       Yes      Yes
#  2                             Assault weapon law?        No      Yes
#  3                  Magazine capacity restriction?        No      Yes
#  4                         Owner license required?        No       No
#  5            Permit required for concealed carry?       NaN      Yes
#  6                 Permit required for open carry?       Yes      Yes
#  7         State preemption of local restrictions?       Yes      Yes
#  8                         NFA weapons restricted?       Yes      Yes
#  9                         Peaceable journey laws?        No       No
#  10  Background checks required for private sales?       Yes      Yes
#  11                                  Red flag law?       Yes      Yes
#
#             Relevant Statutes  \
#  0                     §134-2
#  1              HRS 0134-0003
#  2                        NaN
#  3   HRS134-8(c) HRS134-11(3)
#  4                        NaN
#  5              HRS 0134-0009
#  6                        NaN
#  7                        NaN
#  8                        NaN
#  9                       None
#  10                HRS §134-2
#  11                       NaN
#
#                                                  Notes
#  0   Must be 21 years old to acquire a permit to pu...
#  1   Must be registered with county police chief wi...
#  2   Law bans assault pistols with two or more bann...
#  3   Any magazine with a capacity of more than 10 r...
#  4   No license required to own any firearms in Haw...
#  5   May-Issue by statute, but No-Issue in practice...
#  6   By law, Hawaii is a Licensed Open Carry State,...
#  7   Municipalities may enact and enforce local reg...
#  8   Machine guns, short barreled rifles, short bar...
#  9                              Federal laws observed.
#  10  A person who wants to purchase a handgun or lo...
#  11  Hawaii passed a red flag law in late June 2019...  ,
#                                        Subject/Law Long guns Handguns  \
#  0              State permit required to purchase?        No       No
#  1                           Firearm registration?        No       No
#  2                             Assault weapon law?        No       No
#  3                  Magazine Capacity Restriction?        No       No
#  4                         Owner license required?        No       No
#  5            Permit required for concealed carry?       NaN       No
#  6                 Permit required for open carry?        No       No
#  7         State Preemption of local restrictions?       Yes      Yes
#  8                         NFA weapons restricted?        No       No
#  9                         Peaceable Journey laws?        No       No
#  10  Background checks required for private sales?        No       No
#
#     Relevant statutes                                              Notes
#  0                NaN                                                NaN
#  1                NaN                                                NaN
#  2                NaN                                                NaN
#  3                NaN                                                NaN
#  4                NaN                                                NaN
#  5      Idaho 18-3302  As of July 1, 2020, U.S. citizens and active m...
#  6                NaN  May carry openly without a permit in a vehicle...
#  7                NaN  Cities May regulate the discharge of firearms ...
#  8                NaN  Permitted as long as such possession is in com...
#  9                NaN                            Federal rules observed.
#  10               NaN                                                NaN  ,
#                                        Subject/Law Long guns Handguns  \
#  0              State permit required to purchase?       Yes      Yes
#  1                          Owner permit required?       Yes      Yes
#  2                           Firearm registration?        No       No
#  3           License required for concealed carry?       NaN      Yes
#  4                             Open carry allowed?        No       No
#  5                          Vehicle carry allowed?        No      Yes
#  6         State preemption of local restrictions?   Partial  Partial
#  7                             Assault weapon law?        No       No
#  8                  Magazine capacity restriction?        No       No
#  9                         NFA weapons restricted?       Yes      Yes
#  10      Castle doctrine / stand your ground laws?   Partial  Partial
#  11                        Peaceable journey laws?   Partial      Yes
#  12  Background checks required for private sales?       Yes      Yes
#  13                                  Red flag law?       Yes      Yes
#  14                                Waiting period?       Yes      Yes
#
#                                      Relevant statutes  \
#  0                                         430 ILCS 65
#  1                                         430 ILCS 65
#  2                                                 NaN
#  3    Public Act 098-0063: Firearm Concealed Carry Act
#  4                                       720 ILCS 5/24
#  5    Public Act 098-0063: Firearm Concealed Carry Act
#  6    Public Act 098-0063: Firearm Concealed Carry Act
#  7   Cook Co. Code of Ord. §54-211 Chi. Mun. Code §...
#  8                                                 NaN
#  9                       720 ILCS 5/24 720 ILCS 5/24-2
#  10                                         720 ILCS 5
#  11   Public Act 098-0063: Firearm Concealed Carry Act
#  12                                        430 ILCS 65
#  13  Public Act 100-0607: Firearms Restraining Orde...
#  14                                Public Act 100-0606
#
#                                                  Notes
#  0   FOID (Firearm Owner's Identification card) req...
#  1                                      FOID required.
#  2                                                 NaN
#  3   Shall-issue with limited discretion.[63] Conce...
#  4                                                 NaN
#  5   An Illinois concealed carry license is require...
#  6   Preemption for the regulation and transportati...
#  7   Cook County and the city of Chicago have separ...
#  8   No state-level restrictions. Some local jurisd...
#  9   Automatic firearms, short-barreled shotguns, a...
#  10  Illinois has no stand-your-ground law, however...
#  11  Illinois has state preemption for the transpor...
#  12  The seller must verify the buyer's FOID card w...
#  13  Family members or police can petition a judge ...
#  14  After purchasing a firearm, the waiting period...  ,
#                                        Subject/Law Long guns Handguns  \
#  0              State permit required to purchase?        No       No
#  1                           Firearm registration?        No       No
#  2                             Assault weapon law?        No       No
#  3                  Magazine capacity restriction?        No       No
#  4                         Owner license required?        No       No
#  5           License required for concealed carry?       NaN      Yes
#  6                License required for open carry?    No[66]      Yes
#  7                                  Vehicle carry?       Yes      Yes
#  8         State preemption of local restrictions?       Yes      Yes
#  9                         NFA weapons restricted?        No       No
#  10                                 Shall certify?       Yes      Yes
#  11                        Peaceable journey laws?        No       No
#  12                           Castle Doctrine law?       Yes      Yes
#  13                                Duty to inform?        No       No
#  14  Background checks required for private sales?        No       No
#  15                                  Red flag law?       Yes      Yes
#
#     Relevant Statutes                                              Notes
#  0               None                                                NaN
#  1               None                                                NaN
#  2               None                                                NaN
#  3               None                                                NaN
#  4               None                                                NaN
#  5       IC 35-47-2-3  Shall-Issue. Officially "License to Carry Hand...
#  6       IC 35-47-2-3  May carry handgun openly with license. On May ...
#  7       IC 35-47-2-3           May carry in a vehicle with license.[68]
#  8    IC 35-47-11.1-2                                    Enacted in 2011
#  9      IC 35-47-5-10                             Federal laws observed.
#  10               NaN                  Shall certify within 15 days.[69]
#  11              None                            Federal rules observed.
#  12      IC 35-41-3-2  No duty to retreat from dwelling, curtilage, o...
#  13     IC 35-47-2-24  Indiana law does not require one to disclose p...
#  14              None                                                NaN
#  15  IC 35-47-14-6(b)  The police may temporarily confiscate firearms...  ,
#                                        Subject/Law Long guns Handguns  \
#  0         State Preemption of local restrictions?       Yes      Yes
#  1              State permit required to purchase?        No      Yes
#  2            Permit required for concealed carry?       NaN      Yes
#  3                 Permit required for open carry?       Yes      Yes
#  4                                 Castle Doctrine       Yes      Yes
#  5                           Firearm registration?        No       No
#  6                             Assault weapon law?        No       No
#  7                  Magazine Capacity Restriction?        No       No
#  8                         Owner license required?        No       No
#  9                         NFA weapons restricted?       Yes      Yes
#  10  Background checks required for private sales?        No      Yes
#
#     Relevant Statutes                                              Notes
#  0             724.28  A political subdivision of the state shall not...
#  1             724.15  Permit To Carry may be used in lieu of Permit ...
#  2              724.4  Iowa is a "shall issue" state. An Iowa carry p...
#  3              724.7  Iowa issues a "Permit to Carry Weapons" that i...
#  4          704 707.6  Civil immunity for use of "reasonable force" i...
#  5                NaN                                                NaN
#  6                NaN                                                NaN
#  7                NaN                                                NaN
#  8                NaN                                                NaN
#  9              724.1  Machine guns, destructive devices, etc. illega...
#  10            724.15  A person acquiring a handgun must have an annu...  ,
#                                        Subject/Law Long Guns Handguns  \
#  0              State permit required to purchase?        No       No
#  1                           Firearm registration?        No       No
#  2                             Assault weapon law?        No       No
#  3                  Magazine Capacity Restriction?        No       No
#  4                         Owner license required?        No       No
#  5           License required for concealed carry?       NaN       No
#  6                License required for open carry?        No       No
#  7         State preemption of local restrictions?       Yes      Yes
#  8                         NFA weapons restricted?        No       No
#  9                                  Shall Certify?       Yes      Yes
#  10                        Peaceable journey laws?        No       No
#  11  Background checks required for private sales?        No       No
#
#                                      Relevant Statutes  \
#  0                                                 NaN
#  1                                                 NaN
#  2                                                 NaN
#  3                                                 NaN
#  4                                                 NaN
#  5                        Kansas Chapter 75 Article 7c
#  6                                                 NaN
#  7   Kan. Stat. Ann. § 12-16,124(a), (b) and Kan. S...
#  8                 The Second Amendment Protection Act
#  9                                             48-1906
#  10                                                NaN
#  11                                                NaN
#
#                                                  Notes
#  0                                                 NaN
#  1                                                 NaN
#  2                                                 NaN
#  3                                                 NaN
#  4                                                 NaN
#  5   As of July 1, 2013, you may conceal carry in a...
#  6            May carry openly without permit/license.
#  7                                                 NaN
#  8   Short barreled shotguns, and machine guns must...
#  9                       Shall certify within 15 days.
#  10                            Federal rules observed.
#  11                                                NaN  ,
#                                        Subject/Law Long Guns Handguns  \
#  0              State permit required to purchase?        No       No
#  1                           Firearm registration?        No       No
#  2                             Assault weapon law?        No       No
#  3                  Magazine capacity restriction?        No       No
#  4                         Owner license required?        No       No
#  5           License required for concealed carry?        No       No
#  6                License required for open carry?        No       No
#  7         State preemption of local restrictions?       Yes      Yes
#  8                         NFA weapons restricted?        No       No
#  9                                  Shall certify?       Yes      Yes
#  10                        Peaceable journey laws?        No       No
#  11  Background checks required for private sales?        No       No
#
#     Relevant Statutes                                              Notes
#  0                NaN                                                NaN
#  1                NaN                                                NaN
#  2                NaN                                                NaN
#  3                NaN                                                NaN
#  4                NaN                                                NaN
#  5      KRS § 237.110  Constitutional carry legal as of June 26,2019....
#  6                NaN           May carry openly without permit/license.
#  7       KRS § 65.870  Exception: KRS § 237.115 allows the following ...
#  8                NaN                                                NaN
#  9      KRS § 237.075                      Shall certify within 15 days.
#  10               NaN                            Federal rules observed.
#  11               NaN  People who have a Felony or domestic violence ...  ,
#                                       Subject/Law Long Guns Handguns  \
#  0             State permit required to purchase?        No       No
#  1                          Firearm registration?        No       No
#  2                        Owner license required?        No       No
#  3           Permit required for concealed carry?       NaN      Yes
#  4                Permit required for open carry?        No       No
#  5        State preemption of local restrictions?       Yes      Yes
#  6                            Assault weapon law?        No       No
#  7                 Magazine Capacity Restriction?        No       No
#  8                        NFA weapons restricted?        No       No
#  9  Background checks required for private sales?        No       No
#
#    Relevant Statutes                                              Notes
#  0               NaN                                                NaN
#  1               NaN                                                NaN
#  2               NaN                                                NaN
#  3     LRS 40:1379.3  Louisiana is a "shall issue" state for conceal...
#  4               NaN  Open carry is generally permitted without a li...
#  5               NaN  Local restrictions in place before July 15, 19...
#  6               NaN                                                NaN
#  7               NaN                                                NaN
#  8               NaN                            Federal rules observed.
#  9               NaN                                                NaN  ,
#                                        Subject/Law Long Guns Handguns  \
#  0              State permit required to purchase?        No       No
#  1                           Firearm registration?        No       No
#  2                         Owner license required?        No       No
#  3            Permit required for concealed carry?       NaN       No
#  4                 Permit required for open carry?        No       No
#  5         State preemption of local restrictions?       Yes      Yes
#  6                             Assault weapon law?        No       No
#  7                  Magazine capacity restriction?       No*       No
#  8                         NFA weapons restricted?        No       No
#  9                                  Shall certify?       Yes      Yes
#  10  Background checks required for private sales?        No       No
#
#     Relevant Statutes                                              Notes
#  0                NaN                                                NaN
#  1                NaN                                                NaN
#  2                NaN                                                NaN
#  3       25 MRS §2003  Maine is a "shall issue" state for concealed c...
#  4                NaN                           Open carry is permitted.
#  5                NaN  Local governments may restrict the discharge o...
#  6                NaN                                                NaN
#  7      12 MRS §11214                                                NaN
#  8                NaN                                                NaN
#  9   25 MRSA §2013(3)                      Shall certify within 15 days.
#  10               NaN                                                NaN  ,
#                                        Subject/Law Long Guns Handguns  \
#  0              State permit required to purchase?        No      Yes
#  1                           Firearm registration?        No      Yes
#  2                         Owner license required?        No       No
#  3            Permit required for concealed carry?       NaN      Yes
#  4                 Permit required for open carry?        No      Yes
#  5         State preemption of local restrictions?       Yes      Yes
#  6                             Assault weapon law?       Yes      Yes
#  7                  Magazine capacity restriction?       Yes      Yes
#  8                         NFA weapons restricted?        No       No
#  9   Background checks required for private sales?   Partial      Yes
#  10                                  Red flag law?       Yes      Yes
#
#                                      Relevant Statutes  \
#  0        Md Public Safety Article Section 5-117.1[75]
#  1                                                 NaN
#  2                                                 NaN
#  3                                                 NaN
#  4                                                 NaN
#  5                                                 NaN
#  6   Md Criminal Law Article Section 4-303Firearms ...
#  7                                                 NaN
#  8                                                 NaN
#  9                           GAM Public Safety, §5-124
#  10                                               [77]
#
#                                                  Notes
#  0   A Handgun Qualification License is required, u...
#  1   The state police maintain a permanent record o...
#  2                                                 NaN
#  3   Maryland is a "may issue" state for concealed ...
#  4   Open carry is permitted with a carry license, ...
#  5   Maryland has state preemption for most but not...
#  6   Certain models of firearms are banned as assau...
#  7   Illegal to purchase, sell or manufacture magaz...
#  8   Automatic firearms, SBSs, and SBRs must be own...
#  9   All private transfers of regulated firearms (h...
#  10                                                NaN  ,
#                                        Subject/Law Long Guns Handguns  \
#  0              State permit required to purchase?       Yes      Yes
#  1                           Firearm registration?        No       No
#  2                         Owner license required?       Yes      Yes
#  3           License required for concealed carry?       Yes      Yes
#  4                License required for open carry?       Yes      Yes
#  5         State preemption of local restrictions?        No       No
#  6                             Assault weapon law?       Yes      Yes
#  7                  Magazine Capacity Restriction?       Yes      Yes
#  8                         NFA weapons restricted?       Yes      Yes
#  9   Background checks required for private sales?       Yes      Yes
#  10                                  Red flag law?       Yes      Yes
#
#         Relevant Statutes                                              Notes
#  0   MA Ch. 140 Sec. 129C  Firearm Identification (FID) or license to car...
#  1                    NaN  Although registration is not specifically requ...
#  2   MA Ch. 140 Sec. 129C  Firearm Identification (FID) or license to car...
#  3    MA Ch. 140 Sec. 131  Massachusetts is a "may issue" state for carry...
# ...
#  2   Proof of age and citizenship required for the ...
#  3   Virginia is a "shall issue" state for conceale...
#  4   Open carry is generally allowed without a perm...
#  5   Virginia has state preemption for most but not...
#  6   Proof of age (18+ for long arms, 21+ for pisto...
#  7   Magazines capable of holding more than 20 roun...
#  8   Fully automatic firearms (machine guns) must b...
#  9   As of July 1, 2020, firearms sellers, with som...
#  10  A judge can issue an Extreme Risk Protective O...  ,
#                                        Subject/Law               Long guns  \
#  0              State permit required to purchase?                 Partial
#  1                           Firearm registration?                      No
#  2                         Owner license required?                      No
#  3              Constitutional Right to Bear Arms?                     Yes
#  4            Permit required for concealed carry?                     NaN
#  5                 Permit required for open carry?                      No
#  6         State Preemption of local restrictions?                     Yes
#  7                            Assault weapons law?                     Yes
#  8                 Magazine capacity restrictions?                      No
#  9                         NFA weapons restricted?                 Partial
#  10                        Peaceable Journey laws?                      No
#  11       Castle Doctrine / Stand your ground law?  Not defined - de facto
#  12  Background checks required for private sales?                     Yes
#  13                                  Red flag law?                     Yes
#
#                    Handguns                         Revised Code of Washington  \
#  0                       No                                                NaN
#  1                  Partial                        RCW 09.41.110(9)(a) and (b)
#  2                       No                                                NaN
#  3                      Yes                     WA Constitution art. 1 sec. 24
#  4                      Yes                      RCW 09.41.050 CCW Reciprocity
#  5                       No                         RCW 09.41.050 (in vehicle)
#  6                      Yes                        RCW 09.41.290 RCW 09.41.300
#  7                      Yes                                                NaN
#  8                       No                                                NaN
#  9                  Partial  RCW 09.41.190 RCW 09.41.220 RCW 09.41.225 RCW ...
#  10                      No  RCW 09.41.050 RCW 09.41.060 18 USC § 926A CCW ...
#  11  Not defined - de facto                       RCW 9A.16.050, RCW 9A.16.110
#  12                     Yes                              Initiative 594 (2014)
#  13                     Yes                                                NaN
#
#                                                  Notes
#  0   Must be 21 to purchase a pistol or semiautomat...
#  1   Retail dealers must record and report all reta...
#  2                                                 NaN
#  3                                                 NaN
#  4   Washington is a "shall-issue" state and will g...
#  5   Open carry is lawful in Washington without any...
#  6   State law does not allow more restrictive loca...
#  7   Additionally, I-1639 was passed by voters in N...
#  8                                                 NaN
#  9   Machine guns and short-barreled shotguns—unles...
#  10  Federal travel-with-a-firearm laws apply. Some...
#  11  The Washington State Supreme Court ruled "that...
#  12  Private party firearm transfers must be conduc...
#  13  The police may temporarily take guns away from...  ,
#                                       Subject/Law Long Guns Handguns  \
#  0             State permit required to purchase?        No       No
#  1                          Firearm registration?        No       No
#  2                        Owner license required?        No       No
#  3          License required for concealed carry?       NaN       No
#  4               License required for open carry?        No       No
#  5        State preemption of local restrictions?       Yes      Yes
#  6                            Assault weapon law?        No       No
#  7                        NFA weapons restricted?        No       No
#  8                                 Shall Certify?       Yes      Yes
#  9  Background checks required for private sales?        No       No
#
#    Relevant Statutes                                              Notes
#  0               NaN                                                NaN
#  1               NaN                                                NaN
#  2               NaN                                                NaN
#  3   §61-7-4 §61-7-7  As of May 24, 2016,[199] West Virginia became ...
#  4               NaN  Open carry is generally allowed without a permit.
#  5          §8-12-5a  Pursuant to The Enrolled Public Act of Senate ...
#  6               NaN                                                NaN
#  7               NaN                                                NaN
#  8          §61-7-16                      Shall certify within 30 days.
#  9               NaN                                                NaN  ,
#                                        Subject/Law Long guns Handguns  \
#  0               Constitutional right to bear arms       Yes      Yes
#  1         State preemption of local restrictions?       Yes      Yes
#  2              State permit required to purchase?        No      Yes
#  3           License required for concealed carry?       NaN      Yes
#  4                License required for open carry?        No       No
#  5                         Owner license required?        No       No
#  6           Castle Doctrine/Self Defense Statutes       Yes      Yes
#  7           Castle Doctrine/Self Defense Statutes       Yes      Yes
#  8           Castle Doctrine/Self Defense Statutes       Yes      Yes
#  9                           Firearm registration?        No       No
#  10                            Assault weapon law?        No       No
#  11                Magazine capacity restrictions?        No       No
#  12                        NFA weapons restricted?        No       No
#  13  Background checks required for private sales?        No      NaN
#
#     Relevant Statutes                                              Notes
#  0               1:25  "The people have the right to keep and bear ar...
#  1            66.0409                                                NaN
#  2             175.35  A purchaser is prohibited from receiving a han...
#  3             175.60  Permit is given on a shall-issue basis. Concea...
#  4     947.01 66.0409  Open carry of loaded handguns and long guns an...
#  5             941.29                                                NaN
#  6             895.62  Immunity from prosecution and civil damages in...
#  7             939.48  No duty to retreat in the "dwelling" or owned/...
#  8             940.01  "the state must prove beyond a reasonable doub...
#  9                NaN                                                NaN
#  10               NaN                                                NaN
#  11               NaN                                                NaN
#  12    941.298 941.26  Machine guns allowed, but may not shoot pistol...
#  13               NaN                                                NaN  ,
#                                       Subject/Law Long guns Handguns  \
#  0             State permit required to purchase?        No       No
#  1                          Firearm registration?        No       No
#  2                            Assault weapon law?        No       No
#  3                 Magazine Capacity Restriction?        No       No
#  4                        Owner license required?        No       No
#  5           Permit required for concealed carry?       NaN       No
#  6                Permit required for open carry?        No       No
#  7        State Preemption of local restrictions?       Yes      Yes
#  8                        NFA weapons restricted?        No       No
#  9  Background checks required for private sales?        No       No
#
#     Relevant Statutes                                              Notes
#  0                NaN                                                NaN
#  1                NaN                                                NaN
#  2                NaN                                                NaN
#  3                NaN                                                NaN
#  4                NaN                                                NaN
#  5                NaN  Residents may carry open or concealed without ...
#  6                NaN  No permit required for both residents and non-...
#  7                NaN                                                NaN
#  8                NaN  Wyoming Firearms Freedom Act, passed in 2010, ...
#  9                NaN                                                NaN  ,
#                          Subject/Law Long guns Handguns  Relevant statutes  \
#  0      Permit required to purchase?       Yes      NaN                NaN
#  1             Firearm registration?       Yes      Yes                NaN
#  2               Assault weapon law?        No       No                NaN
#  3    Magazine capacity restriction?        No       No                NaN
#  4          Concealed carry allowed?       NaN       No                NaN
#  5  License required for open carry?       Yes      Yes                NaN
#  6           NFA weapons restricted?       Yes      Yes                NaN
#  7           Peaceable journey laws?        No       No                NaN
#
#                                                 Notes
#  0  A license is required to possess or import lon...
#  1  All firearms must be registered with the Ameri...
#  2  All handguns and centerfire firearms banned; O...
#  3                                                NaN
#  4                        Concealed carry is illegal.
#  5  Open carry is legal for holders of a valid Lic...
#  6  Explosive weapons, machine guns, gas guns, sho...
#  7                        Federal law (FOPA) applies.  ,
#                               Subject/Law Long guns  Handguns  \
#  0           Permit required to purchase?       Yes       Yes
#  1                 Owner License Required       Yes       Yes
#  2                  Firearm registration?       Yes       Yes
#  3  License required for concealed carry?       NaN       Yes
#  4       License required for open carry?       Yes       Yes
#  5                     Assault weapon law        No        No
#  6         Magazine capacity restriction?        No        No
#  7                NFA weapons restricted?       Yes       Yes
#  8                             Castle law  Yes[211]  Yes[211]
#
#    Relevant Statutes                                              Notes
#  0      60103, 60106                                     FOID required.
#  1             60106                                                NaN
#  2             60110                                                NaN
#  3             60109  Shall Issue. Bill 296-32 passed by legislature...
#  4               NaN                                FOID required.[210]
#  5               NaN                                                NaN
#  6               NaN                                                NaN
#  7               NaN  SBR, SBS, Machine guns, and silencers are proh...
#  8               NaN                                                NaN  ,
#                               Subject/Law Long guns Handguns  \
#  0           Permit required to purchase?       Yes      Yes
#  1                  Firearm registration?        No       No
#  2                    Assault weapon law?        No       No
#  3         Magazine capacity restriction?       Yes      Yes
#  4  License required for concealed carry?       NaN       No
#  5       License required for open carry?       NaN       No
#  6                NFA weapons restricted?       Yes      Yes
#  7                Peaceable journey laws?        No       No
#
#     Relevant statutes                                              Notes
#  0                NaN  A license is required to purchase guns or ammu...
#  1                NaN  Registration of firearms has been ruled uncons...
#  2                NaN  Ban on assault weapons was ruled unconstitutio...
#  3                NaN                  No magazines over 10 rounds.[214]
#  4                NaN  Concealed carry is protected under the Second ...
#  5                NaN  The general ban on carrying operable firearms ...
#  6                NaN  Short barreled shotguns, short barreled rifles...
#  7                NaN                        Federal law (FOPA) applies.  ,
#                                       Subject/Law Long guns Handguns  \
#  0                   Permit required to purchase?       Yes      Yes
#  1                          Firearm registration?       Yes      Yes
#  2                            Assault weapon law?        No       No
#  3                 Magazine capacity restriction?        No       No
#  4                        Owner license required?       Yes      Yes
#  5           Permit required for concealed carry?       Yes      Yes
#  6                            Open carry allowed?        No       No
#  7                        NFA weapons restricted?       Yes      Yes
#  8                        Peaceable journey laws?        No       No
#  9  Background checks required for private sales?       Yes      Yes
#
#     Relevant statutes                                              Notes
#  0                NaN                                                NaN
#  1                NaN                                                NaN
#  2                NaN                                                NaN
#  3                NaN                                                NaN
#  4                NaN  As of January 1, 2020, the owner license and c...
#  5                NaN  As of January 1, 2020, shall-issue.[215]Previo...
#  6                NaN  Permitless open carry was technically allowed ...
#  7                NaN                                                NaN
#  8                NaN                        Federal law (FOPA) applies.
#  9                NaN                                                NaN  ,
#                               Subject/Law Long guns Handguns  \
#  0           Permit required to purchase?       Yes      Yes
#  1                  Firearm registration?       Yes      Yes
#  2                    Assault weapon law?       Yes      Yes
#  3         Magazine capacity restriction?       Yes      Yes
#  4  License required for concealed carry?       NaN      Yes
#  5                    Open carry allowed?        No       No
#  6                NFA weapons restricted?       Yes      Yes
#  7                Peaceable journey laws?        No       No
#
#     Relevant statutes                                              Notes
#  0                NaN  A license is required to purchase any firearm ...
#  1                NaN  All firearms must be registered with the Virgi...
#  2                NaN     Assault weapons and .50 BMG rifles prohibited.
#  3                NaN                                                NaN
#  4                NaN  The territory currently has a "may issue" poli...
#  5                NaN                          Open carry is prohibited.
#  6                NaN  Automatic firearms and short barreled shotguns...
#  7                NaN                        Federal law (FOPA) applies.  ]

# %%
res = requests.get(URL)
soup = BeautifulSoup(res.content, 'html.parser')
headings = soup.find_all('span', class_='mw-headline')

temp = []
for i in headings:
    temp.append(i.get("id"))
state_names = temp[1:-4]
state_names
# Out:
# ['Alabama',
#  'Alaska',
#  'Arizona',
#  'Arkansas',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'Delaware',
#  'District_of_Columbia',
#  'Florida',
#  'Georgia',
#  'Hawaii',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Kansas',
#  'Kentucky',
#  'Louisiana',
#  'Maine',
#  'Maryland',
#  'Massachusetts',
#  'Michigan',
#  'Minnesota',
#  'Mississippi',
#  'Missouri',
#  'Montana',
#  'Nebraska',
#  'Nevada',
#  'New_Hampshire',
#  'New_Jersey',
#  'New_Mexico',
#  'New_York',
#  'North_Carolina',
#  'North_Dakota',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Rhode_Island',
#  'South_Carolina',
#  'South_Dakota',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'Vermont',
#  'Virginia',
#  'Washington',
#  'West_Virginia',
#  'Wisconsin',
#  'Wyoming',
#  'US_Territories',
#  'American_Samoa',
#  'Guam',
#  'Northern_Mariana_Islands',
#  'Puerto_Rico']

# %%
mapping = {}
for i in range(len(state_names)):
    mapping[ state_names[i] ] = states[i]

# %%
# a = [
#     ["California", "yes", "no"],
#     [4, 5, 6]
# ]
# pd.DataFrame(a, columns=["State Name", "Ques 1", "c"])

# State permit required to purchase?
ques=["State permit required to purchase?", "Firearm registration?", "Owner license required?", "Background checks required for private sales?"]

# Traverse the list
master_arr = []
for state in mapping:
    temp = [state]

    # print (state)
    df = mapping[state]
    try:
        df['Subject/Law'] = df['Subject/Law'].str.strip()
        df = df.set_index("Subject/Law")
    except:
        df['Subject/law'] = df['Subject/law'].str.strip()
        df = df.set_index("Subject/law")
#     df.at( index, row )
    for q in ques:
        try:
            temp.append( df.at[q, 'Long guns'] )
        except Exception as e:
            # print (e, state, q)
            try:
                temp.append( df.at[q, 'Long Guns'] )
            except Exception as e:
                # print (e, state, q)
                temp.append(float('nan'))

    master_arr.append(temp)

laws_df = pd.DataFrame(master_arr, columns=["State"] + ques)

# %%
laws_df.head()
# Out:
#         State State permit required to purchase? Firearm registration?  \
# 0     Alabama                                 No                    No
# 1      Alaska                                 No                    No
# 2     Arizona                                 No                   NaN
# 3    Arkansas                                 No                    No
# 4  California                            Partial                   Yes
#
#   Owner license required? Background checks required for private sales?
# 0                      No                                            No
# 1                      No                                            No
# 2                      No                                            No
# 3                      No                                            No
# 4                      No                                           Yes

# %%
#To rename the States so they would match other data frames
new_laws_df = laws_df.replace({'State': {'District_of_Columbia': 'District of Columbia', 'New_Hampshire': 'New Hampshire', 'New_Jersey': 'New Jersey', 
                           'New_Mexico': 'New Mexico', 'New_York': 'New York', 'North_Carolina': 'North Carolina', 
                           'North_Dakota': 'North Dakota', 'Rhode_Island': 'Rhode Island', 'West_Virginia': 'West Virginia',
                           'South_Carolina': 'South Carolina', 'South_Dakota': 'South Dakota', 'Puerto_Rico': 'Puerto Rico'}})
new_laws_df.head()
# Out:
#         State State permit required to purchase? Firearm registration?  \
# 0     Alabama                                 No                    No
# 1      Alaska                                 No                    No
# 2     Arizona                                 No                   NaN
# 3    Arkansas                                 No                    No
# 4  California                            Partial                   Yes
#
#   Owner license required? Background checks required for private sales?
# 0                      No                                            No
# 1                      No                                            No
# 2                      No                                            No
# 3                      No                                            No
# 4                      No                                           Yes

# %%
#To drop Specific external states that were not necessary for the necessary data
drop_laws_df = new_laws_df.drop([55, 54, 53, 52, 51])
drop_laws_df.head()
# Out:
#         State State permit required to purchase? Firearm registration?  \
# 0     Alabama                                 No                    No
# 1      Alaska                                 No                    No
# 2     Arizona                                 No                   NaN
# 3    Arkansas                                 No                    No
# 4  California                            Partial                   Yes
#
#   Owner license required? Background checks required for private sales?
# 0                      No                                            No
# 1                      No                                            No
# 2                      No                                            No
# 3                      No                                            No
# 4                      No                                           Yes

# %%
clean_laws_df = drop_laws_df.rename(columns = {'State permit required to purchase?':'State_permit_required_to_purchase','Firearm registration?':'Firearm_registration','Owner license required?':'Owner_license_required','Background checks required for private sales?':'Background_checks_required_for_private_sales'})
clean_laws_df.head()
# Out:
#         State State_permit_required_to_purchase Firearm_registration  \
# 0     Alabama                                No                   No
# 1      Alaska                                No                   No
# 2     Arizona                                No                  NaN
# 3    Arkansas                                No                   No
# 4  California                           Partial                  Yes
#
#   Owner_license_required Background_checks_required_for_private_sales
# 0                     No                                           No
# 1                     No                                           No
# 2                     No                                           No
# 3                     No                                           No
# 4                     No                                          Yes

# %% [markdown]
# Final Clean before Loading

# %%
clean_violence_df.columns= clean_violence_df.columns.str.lower()
clean_violence_df.head(2)
# Out:
#         id       date      state       city  \
# 0  1747443  27-Jul-20    Arizona     Tucson
# 1  1747425  26-Jul-20  Tennessee  Nashville
#
#                              address killed injured
# 0               25 W Calle Concordia      1       0
# 1  500 block of Charles E Davis Blvd      1       0

# %%
clean_map_df.columns= new_map_df.columns.str.lower()
clean_map_df.head()
# Out:
#         state          city
# 0     Arizona        Tucson
# 1   Tennessee     Nashville
# 2        Ohio  Grand Rapids
# 3  California   Los Angeles
# 4     Florida         Largo

# %%
type_df.columns= type_df.columns.str.lower()
type_df.head(2)
# Out:
#         id      type
# 0  1747443  Accident
# 1  1747425  Accident

# %%
clean_laws_df.columns= clean_laws_df.columns.str.lower()
clean_laws_df.head(2)
# Out:
#      state state_permit_required_to_purchase firearm_registration  \
# 0  Alabama                                No                   No
# 1   Alaska                                No                   No
#
#   owner_license_required background_checks_required_for_private_sales
# 0                     No                                           No
# 1                     No                                           No

# %% [markdown]
# # Load into PostgreSQL DB

# %%
rds_connection_string = f'{username}:{password}@localhost:5432/gun_violence'
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
clean_laws_df.to_sql(name='Gun_Laws', con=engine, if_exists='append', index=False)
type_df.to_sql(name='Type', con=engine, if_exists='append', index=False)
clean_map_df.to_sql(name='State', con=engine, if_exists='append', index=False)
clean_violence_df.to_sql(name='Violence', con=engine, if_exists='append', index=False)

# %%
engine.table_names()
# Out:
# ['Gun_Laws', 'State', 'Type', 'Violence']
